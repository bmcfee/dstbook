# %% [markdown]
# # Algebra

# %% [markdown]
# ## Variables

# %% [markdown]
# ## Rules of algebra

# %% [markdown]
# ## Polynomials and the fundamental theorem of algebra

# %% [markdown]
# ## Common pitfalls
